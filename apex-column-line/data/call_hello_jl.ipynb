# %%
print("call hello.jl")
# Out:
# call hello.jl

# %%
import os

# %%
# %%time
os.popen("julia hello.jl").read()
# Out:
# CPU times: user 4.89 ms, sys: 181 µs, total: 5.07 ms
# Wall time: 920 ms
# 'hello jl to you\n'
