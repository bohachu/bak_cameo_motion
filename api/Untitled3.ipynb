# %%
using CSV

# %%
for i in collect(Base.loaded_modules)
    println(i)
end
# Out:
# MbedTLS_jll [c8ffd9c3-330d-5841-b78e-0817d7145fa1] => MbedTLS_jll
# Random [9a3f8284-a2c9-5f02-9a11-845980a1fd5c] => Random
# RecipesBase [3cdcf5f2-1ef4-517c-9805-6587b60abb01] => RecipesBase
# VersionParsing [81def892-9a0e-5fdd-b105-ffc91e053289] => VersionParsing
# Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] => Plots
# LibGit2 [76f85450-5226-5b5a-8eaa-529ad045b433] => LibGit2
# DataValueInterfaces [e2d170a0-9d28-54be-80f0-106bbe20a464] => DataValueInterfaces
# Pkg [44cfe95a-1eb2-52ea-b672-e2afdf69b78f] => Pkg
# InvertedIndices [41ab1584-1d38-5bbf-9106-f11c6c58b48f] => InvertedIndices
# SHA [ea8e919c-243c-51af-8825-aaa63cd721ce] => SHA
# TableTraits [3783bdb8-4a98-5b6b-af9a-565f29a5fe9c] => TableTraits
# IniFile [83e8ac13-25f8-5344-8a64-a9f2b223428f] => IniFile
# ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4] => ColorSchemes
# SortingAlgorithms [a2af1166-a08f-5f64-846c-94a0d3cef48c] => SortingAlgorithms
# Gumbo_jll [528830af-5a63-567c-a44a-034ed33b8444] => Gumbo_jll
# ...

# %%
Base.loaded_modules
# Out:
# Dict{Base.PkgId,Module} with 134 entries:
#   MbedTLS_jll [c8ffd9c3-330d-5841-b78e-0817d7145… => MbedTLS_jll
#   Random [9a3f8284-a2c9-5f02-9a11-845980a1fd5c]   => Random
#   RecipesBase [3cdcf5f2-1ef4-517c-9805-6587b60ab… => RecipesBase
#   VersionParsing [81def892-9a0e-5fdd-b105-ffc91e… => VersionParsing
#   Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]    => Plots
#   LibGit2 [76f85450-5226-5b5a-8eaa-529ad045b433]  => LibGit2
#   DataValueInterfaces [e2d170a0-9d28-54be-80f0-1… => DataValueInterfaces
#   Pkg [44cfe95a-1eb2-52ea-b672-e2afdf69b78f]      => Pkg
#   InvertedIndices [41ab1584-1d38-5bbf-9106-f11c6… => InvertedIndices
#   SHA [ea8e919c-243c-51af-8825-aaa63cd721ce]      => SHA
#   TableTraits [3783bdb8-4a98-5b6b-af9a-565f29a5f… => TableTraits
#   IniFile [83e8ac13-25f8-5344-8a64-a9f2b223428f]  => IniFile
#   ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119… => ColorSchemes
#   SortingAlgorithms [a2af1166-a08f-5f64-846c-94a… => SortingAlgorithms
# ...
